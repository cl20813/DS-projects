# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import concurrent.futures
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# The goal of the project is to predict policy holders who are likely to change their insurer to other companies. This is a classification problem with binary response variable "convert_ind", where 0 indicates the policy holder continues to use Travelers.

# %%
df = pd.read_csv("C:\\Users\\joonw\\trav\\trav_dataset1.csv")

# %% [markdown]
# ### Spliting dataset into training set and testing set

# %%
# test_set = df[df['split']=='Test']  # all 0 for test data to prevent cheating

# test_set = df.sample(frac=0.2, random_state=24)
# test_mask = df.index.isin(test_set.index)
# rain_set = df.loc[~test_mask,:].reset_index(drop=True)
# test_set = test_set.reset_index(drop=True)

from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, stratify=df['convert_ind'], random_state=24)

train_set = train_set.drop(columns=['split'])
test_set = test_set.drop(columns=['split'])

# Separate features and target from the entire training set
train_y = train_set['convert_ind']
train_x = train_set.drop(columns=['convert_ind'])

test_y = test_set['convert_ind']
test_x = test_set.drop(columns=['convert_ind'])

# %% [markdown]
# ### Parameter Opitmization
#
# It seems grid search is more efficient than RandomizedSearch

# %% [markdown]
# Grid search

# %%
def evaluate_model(params, train_x, train_y, skf):
    """Evaluate a model with the given parameters using cross-validation."""
    train_set = lgb.Dataset(train_x, label=train_y)
    
    # Perform cross-validation
    cv_results = lgb.cv(
        params,
        train_set,
        num_boost_round=2000,
        folds=skf.split(train_x, train_y),
        metrics='auc',
        seed=42
    )
    
    # Get the best AUC score
    score = max(cv_results['valid auc-mean'])
    return score

# Parameter grid for hyperparameter tuning
param_grid = {
    'num_leaves': np.arange(10, 20),
    'learning_rate': [0.005, 0.01, 0.02, 0.03],
    'feature_fraction': [0.75, 0.8, 0.85],
    'min_data_in_leaf': [10, 20, 30],
    'lambda_l1': [0, 0.1, 1],
    'lambda_l2': [0, 0.1, 1],
    'early_stopping_rounds':50
}

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
best_score = 0
best_params = None

# Create a list of all parameter combinations
param_combinations = [
    {
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'metric': 'auc',
        'num_leaves': num_leaves,
        'learning_rate': learning_rate,
        'feature_fraction': feature_fraction,
        'min_data_in_leaf': min_data_in_leaf,
        'lambda_l1': lambda_l1,
        'lambda_l2': lambda_l2,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'random_state': 42,
        'is_unbalance': True
    }
    for num_leaves in param_grid['num_leaves']
    for learning_rate in param_grid['learning_rate']
    for feature_fraction in param_grid['feature_fraction']
    for min_data_in_leaf in param_grid['min_data_in_leaf']
    for lambda_l1 in param_grid['lambda_l1']
    for lambda_l2 in param_grid['lambda_l2']
]

# Evaluate parameter combinations in parallel
with concurrent.futures.ThreadPoolExecutor(max_workers=32) as executor:
    futures = [
        executor.submit(evaluate_model, params, train_x, train_y, skf)
        for params in param_combinations
    ]
    for future, params in zip(concurrent.futures.as_completed(futures), param_combinations):
        score = future.result()
        print(f"Params: {params}, AUC: {score}")
        if score > best_score:
            best_score = score
            best_params = params
# Out:
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755706985074343
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752097797607799
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675680437448145
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755750598894166
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754445595091672
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752446669186495
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755967270644884
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751880832388013
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752672526506066
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754975196143137
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753432831628664
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675628435761298
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755697710741408
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752037493903278
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754388550216378
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750554612485908
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6757682796403872
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753773875526103
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6757200596429342
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752296075705629
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753195207091447
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755146173961458
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675216448372081
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752003954852215
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749292228390907
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754555062709082
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754976902920251
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752747679472659
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751316416475939
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753861862665397
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752689700185516
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752500259101818
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753990824147842
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752875654940353
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675080975855507
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753349631584431
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753080887971461
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754021417493951
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754043306156332
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755079796250081
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753562842050898
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754282376123784
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675457384659197
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755702218360833
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6755362780237849
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753169517483525
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754108874132726
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753613554825386
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754715828891437
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751003531530277
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747913522489687
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675595426196997
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6756208437686128
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754305831414769
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.67505929430142
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6756329659102303
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754332697638341
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750483207087241
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749252506106495
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748755829046329
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750499000483079
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747624275265982
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750575528719822
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.67486314612534
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751376059102967
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751397878218117
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675172962363601
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751093962527623
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675053830855686
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750217410787956
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752021653496665
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750390158213382
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751738262841153
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748763818620956
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753931181641397
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753177143728335
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753471014743603
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753589492353747
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675262412493861
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745674449610968
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.005, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749863804359743
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754299872289089
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748543742725825
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749418798750272
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675252290916908
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750005508389412
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675254249039942
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749745356501242
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748934616998791
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675180820620161
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747375362390294
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747986755392851
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748895847873508
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746550037804249
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674937739913538
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749987988410876
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748134627801333
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754610224110418
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674669297994888
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752191527828625
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749939029713679
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.67547981757365
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748878221254649
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674779959555033
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750161087595721
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747700371807399
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675026574531349
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.75, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749884136630404
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745198842967798
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747257519014205
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674874720491136
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745784515602138
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747585064016975
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743103323877393
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747509893318845
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747349014028606
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745753663350622
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743678875032951
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747366483912254
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746238301839199
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746998036065607
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746733191434466
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747184047341758
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.67424670168766
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745457327489992
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745142472842811
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746803906460801
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6744405718198867
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749910641671975
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747542730004421
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747842133550039
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745569603800448
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748761616165174
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674947358328516
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6737984191426227
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6740027233555649
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750367277722676
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745029710249318
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743595297595957
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6742981498244094
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6744119726747225
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6740644120015051
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6742692451819867
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743780610562504
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6735095023631824
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6735966932208447
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6734995212706756
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746213554739287
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6741408983413744
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(10), 'learning_rate': 0.01, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6742277023774507
# ...
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743114687542622
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6749739360744953
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748980742416556
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675214083857371
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.8, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743408632183703
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6744231853882385
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6742940498470468
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6744044648842106
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747434460320509
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6740922663974327
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6740497649332869
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743317512503619
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748331441279035
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750400773966383
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746774842374992
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745844356320468
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750994886677544
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.674183247764294
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747862964862954
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6744797937923662
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6739976836619285
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743704504137447
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745917033326684
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6743434671257109
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745675125989872
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745077482848698
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745239631583064
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746606305027021
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751414913959288
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6746013003323362
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6745153312895005
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(12), 'learning_rate': 0.03, 'feature_fraction': 0.85, 'min_data_in_leaf': 30, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6747446554565067
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6748291553121974
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751399919488427
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750986144652468
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6750521878285467
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751466962509088
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751573253467533
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752172076932671
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754142065534159
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 10, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753584961902787
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754262330555293
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6752036705828033
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753673919559645
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753250731527525
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6754182771770625
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.675320999782058
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6751822329144521
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 0.1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753841096046559
# Params: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': np.int64(13), 'learning_rate': 0.005, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'is_unbalance': True}, AUC: 0.6753851775858088

# %% [markdown]
# ### previous code

# %%
param_grid = {
    'num_leaves': [15, 31, 63],
    'learning_rate': [0.01, 0.05, 0.1],
    'feature_fraction': [0.6, 0.8, 1.0]
}

best_score = 0
best_params = None

for num_leaves in param_grid['num_leaves']:
    for learning_rate in param_grid['learning_rate']:
        for feature_fraction in param_grid['feature_fraction']:
            # Update parameters
            params = {
                'objective': 'binary',
                'boosting_type': 'gbdt',
                'metric': 'auc',
                'num_leaves': num_leaves,
                'learning_rate': learning_rate,
                'feature_fraction': feature_fraction,
                'bagging_fraction': 0.8,
                'bagging_freq': 5,
                'random_state': 42,
                'early_stopping_round': 50  # Include early stopping here
            }
            
            # Perform cross-validation
            cv_results = lgb.cv(
                params,
                train_set,
                num_boost_round=1000,
                nfold=10,
                metrics='auc',
                seed=42
            )
            
            # Get the best score
            # print(cv_results.keys())
            score = max(cv_results['valid auc-mean'])  # Access the mean AUC
            if score > best_score:
                best_score = score
                best_params = params

# Print the best parameters and score
print("Best Parameters:", best_params)
print("Best CV AUC Score:", best_score)

# %% [markdown]
# Best Parameters: {'objective': 'binary', 'boosting_type': 'gbdt', 'metric': 'auc', 'num_leaves': 15, 'learning_rate': 0.01, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'random_state': 42, 'early_stopping_round': 50}
# Best CV AUC Score: 0.677994801447962

# %% [markdown]
# ### Modeling after Optimizing Tuning Parameters

# %%
# Define the best hyperparameters from cross-validation
best_params = {
    'objective': 'binary',
    'boosting_type': 'gbdt',
    'metric': 'auc',
    'num_leaves': 15,  # Example: From the grid search
    'learning_rate': 0.01,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'random_state': 42,
    'early_stopping_rounds': 50,
}

# Create the full LightGBM dataset
full_train_dataset = lgb.Dataset(train_x, label=train_y)

# Define a logging callback
callbacks = [lgb.log_evaluation(period=50)]

# Train the model on the full training set
final_model = lgb.train(
    best_params,
    full_train_dataset,
    num_boost_round=2000,  # Use a high value to allow full convergence
    valid_sets=[full_train_dataset],
    valid_names=['train'],
    callbacks=callbacks  # Use callbacks for logging
)

# Save the model for future use
final_model.save_model('final_model.txt')

# Evaluate on the test set
test_y = test_set['convert_ind']
test_x = test_set.drop(columns=['convert_ind'])

test_pred = final_model.predict(test_x)
test_auc = roc_auc_score(test_y, test_pred)
print(f"Test AUC: {test_auc:.4f}")

# %% [markdown]
# ### Results

# %% [markdown]
# Confusion matrix

# %%
# view confusion-matrix
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_y, test_pred)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[3573    0]
#  [ 360    0]]
#
# True Positives(TP) =  3573
#
# True Negatives(TN) =  0
#
# False Positives(FP) =  0
#
# False Negatives(FN) =  360

# %% [markdown]
# Classification matrix

# %%
print(classification_report(test_y, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      3573
#          1.0       0.00      0.00      0.00       360
#
#     accuracy                           0.91      3933
#    macro avg       0.45      0.50      0.48      3933
# weighted avg       0.83      0.91      0.86      3933
# c:\Users\joonw\anaconda3\envs\jl2815\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\joonw\anaconda3\envs\jl2815\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\joonw\anaconda3\envs\jl2815\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
